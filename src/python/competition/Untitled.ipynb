# %%
import matplotlib.pyplot as plt
from numpy.random import rand
a = rand(100)
b = rand(100)
plt.scatter(a,b)
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy.random import normal,rand
x = normal(size=200)
plt.hist(x,bins=30)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0,10,100)
b = np.exp(-a)
plt.plot(a,b)
plt.show()

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

data1 = np.loadtxt('data2.csv', delimiter=',')
data2 = np.loadtxt('data3.csv', delimiter=',')
input1 = data1[:,0]
output11 = data1[:,1]
output21= data2[:,1]
output12 = data1[:,2]
output22= data2[:,2]

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

x = np.linspace(-6,6,1000)

ax1.plot(input1, output11, color='pink', linestyle='solid', label='A(average)')
ax1.plot(input1, output21, color='lightblue', linestyle='solid', label='C(average)')
ax1.plot(input1, output12, color='red', linestyle='solid',label='A(max)')
ax1.plot(input1, output22, color='blue', linestyle='solid',label='C(max)')

ax1.legend()
ax1.set_title('ga mario')
ax1.set_xlabel('generation')
ax1.set_ylabel('reward')
ax1.grid(True)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

data1 = np.loadtxt('data5.csv', delimiter=',')
data2 = np.loadtxt('data6.csv', delimiter=',')
data3 = np.loadtxt('data7.csv', delimiter=',')
data4 = np.loadtxt('data8.csv', delimiter=',')

input1 = data1[:,0]
output11 = data1[:,2]
output21= data2[:,2]
output31 = data3[:,2]
output41= data4[:,2]

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

x = np.linspace(-6,6,1000)

ax1.plot(input1, output11, color='black', linestyle='solid', label='base')
ax1.plot(input1, output21, color='blue', linestyle='solid', label='n')
ax1.plot(input1, output31, color='red', linestyle='solid',label='k')
ax1.plot(input1, output41, color='green', linestyle='solid',label='r')

ax1.legend()
ax1.set_title('max')
ax1.set_xlabel('generation')
ax1.set_ylabel('reward')
ax1.grid(True)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

data1 = np.loadtxt('data5.csv', delimiter=',')
data2 = np.loadtxt('data6.csv', delimiter=',')
data3 = np.loadtxt('data7.csv', delimiter=',')
data4 = np.loadtxt('data8.csv', delimiter=',')

input1 = data1[:,0]
output11 = data1[:,1]
output21= data2[:,1]
output31 = data3[:,1]
output41= data4[:,1]

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

x = np.linspace(-6,6,1000)

ax1.plot(input1, output11, color='black', linestyle='solid', label='base')
ax1.plot(input1, output21, color='blue', linestyle='solid', label='n')
ax1.plot(input1, output31, color='red', linestyle='solid',label='k')
ax1.plot(input1, output41, color='green', linestyle='solid',label='r')

ax1.legend()
ax1.set_title('average')
ax1.set_xlabel('generation')
ax1.set_ylabel('reward')
ax1.grid(True)
